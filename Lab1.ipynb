# %%
import numpy as np
import pandas as pd
# Set option manually
pd.set_option('display.max_columns', 40) 
pd.set_option('display.max_rows', 40)

# %% [markdown]
# # Compile Analysis Frame

# %% [markdown]
# Starting with outcomes DataFrame, it holds the "ground truth" of exciting projects from a business perspective

# %%
dfout = pd.read_csv('Data/outcomes.csv', index_col=[0])

# %%
mask = dfout.select_dtypes(include='object').columns
dfout.loc[:, mask] = dfout.loc[:, mask].replace({'f': 0, 't': 1, np.nan: 0}).fillna(0).astype(int)
dfout
# Out:
# C:\Users\maike\AppData\Local\Temp\ipykernel_10808\357046988.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfout.loc[:, mask] = dfout.loc[:, mask].replace({'f': 0, 't': 1, np.nan: 0}).fillna(0).astype(int)
#                                   is_exciting  \
# projectid
# ffffc4f85b60efc5b52347df489d0238            0
# ffffac55ee02a49d1abc87ba6fc61135            0
# ffff97ed93720407d70a2787475932b0            0
# ffff418bb42fad24347527ad96100f81            0
# ffff2d9c769c8fb5335e949c615425eb            1
# ...                                       ...
# 0000ee613c92ddc5298bf63142996a5c            0
# 0000b38bbc7252972f7984848cf58098            0
# 00002d691c05c51a5fdfbb2baef0ba25            0
# 00002bff514104264a6b798356fdd893            0
# ...

# %%
dfout.select_dtypes('object').replace({'f':False, 't':True, np.nan:False})*1
# Out:
#                                projectid  is_exciting  \
# 0       ffffc4f85b60efc5b52347df489d0238            0
# 1       ffffac55ee02a49d1abc87ba6fc61135            0
# 2       ffff97ed93720407d70a2787475932b0            0
# 3       ffff418bb42fad24347527ad96100f81            0
# 4       ffff2d9c769c8fb5335e949c615425eb            1
# ...                                  ...          ...
# 619321  0000ee613c92ddc5298bf63142996a5c            0
# 619322  0000b38bbc7252972f7984848cf58098            0
# 619323  00002d691c05c51a5fdfbb2baef0ba25            0
# 619324  00002bff514104264a6b798356fdd893            0
# 619325  00001ccc0e81598c4bd86bacb94d7acb            0
#
#         at_least_1_teacher_referred_donor  fully_funded  \
# 0                                       0             0
# 1                                       0             1
# 2                                       0             1
# 3                                       0             0
# ...
